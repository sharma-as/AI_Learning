# %%
from huggingface_hub import login
login("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")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:657, in hf_raise_for_status(response, endpoint_name)
#     656 try:
# --> 657     response.raise_for_status()
#     658 except httpx.HTTPStatusError as e:
#
# File /opt/anaconda3/lib/python3.13/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://huggingface.co/api/whoami-v2'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/hf_api.py:1989, in HfApi._inner_whoami(self, token)
#    1988 try:
# -> 1989     hf_raise_for_status(r)
#    1990 except HfHubHTTPError as e:
#
# File /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:752, in hf_raise_for_status(response, endpoint_name)
#     750 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     751 # as well (request id and/or server error message)
# --> 752 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: Client error '401 Unauthorized' for url 'https://huggingface.co/api/whoami-v2' (Request ID: Root=1-69b38001-34066daa39731e70467c4d10;158da4bd-64cb-4e75-94b8-68de1e2af160)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# Invalid username or password.
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# /var/folders/4d/k1p7l1pj1j71fp38qlcwvftm0000gn/T/ipykernel_52835/2013001111.py in ?()
#       1 from huggingface_hub import login
# ----> 2 login("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")
#
# /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/_login.py in ?(token, add_to_git_credential, skip_if_logged_in)
#     108                 "`add_to_git_credential=True` in this function directly or "
#     109                 "`--add-to-git-credential` if using via `hf`CLI if "
#     110                 "you want to set the git credential as well."
#     111             )
# --> 112         _login(token, add_to_git_credential=add_to_git_credential)
#     113     elif is_notebook():
#     114         notebook_login(skip_if_logged_in=skip_if_logged_in)
#     115     else:
#
# /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/_login.py in ?(token, add_to_git_credential)
#     372
#     373     if token.startswith("api_org"):
#     374         raise ValueError("You must use your personal account token, not an organization token.")
#     375
# --> 376     token_info = whoami(token)
#     377     permission = token_info["auth"]["accessToken"]["role"]
#     378     logger.info(f"Token is valid (permission: {permission}).")
#     379
#
# /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py in ?(*args, **kwargs)
#      85                 validate_repo_id(arg_value)
#      86
#      87         kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#      88
# ---> 89         return fn(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/hf_api.py in ?(self, token, cache)
#    1972         if cache and (cached_token := self._whoami_cache.get(token)):
#    1973             return cached_token
#    1974
#    1975         # Call Hub
# -> 1976         output = self._inner_whoami(token=token)
#    1977
#    1978         # Cache result and return
#    1979         if cache:
#
# /opt/anaconda3/lib/python3.13/site-packages/huggingface_hub/hf_api.py in ?(self, token)
#    1999                         "Note that HF_TOKEN takes precedence over `hf auth login`."
#    2000                     )
#    2001                 elif token == _get_token_from_file():
#    2002                     error_message += " The token stored is invalid. Please run `hf auth login` to update it."
# -> 2003                 raise HfHubHTTPError(error_message, response=e.response) from e
#    2004             if e.response.status_code == 429:
#    2005                 error_message = (
#    2006                     "You've hit the rate limit for the /whoami-v2 endpoint, which is intentionally strict for security reasons."
#
# HfHubHTTPError: Invalid user token.

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch  

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

prompt = "In the future, AI agents will"
inputs = tokenizer.encode(prompt, return_tensors="pt")
outputs = model.generate(inputs, max_length=60, temperature=0.8, top_p=0.9, do_sample=True, 
                         pad_token_id=tokenizer.eos_token_id)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
